# %% [markdown]
# <a href="https://colab.research.google.com/github/jackychh7878/Colab_AI_Project/blob/main/Word2Vec_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Word2Vec Model
#
# In this project, I'm going to build a Word2Vec model using the game of thrones books
#
# Data Source: https://www.kaggle.com/datasets/khulasasndh/game-of-thrones-books

# %%
import os
import sys
import numpy as np
import pandas as pd
import nltk
import gensim
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
dir="/content/data"
os.listdir(dir)
# Out:
# ['002ssb.txt', '001ssb.txt', '003ssb.txt', '005ssb.txt', '004ssb.txt']

# %%
filename="004ssb.txt"
os.path.join(dir, filename)
# Out:
# '/content/data/004ssb.txt'

# %% [markdown]
# # Step 1: Preprocessing the sentence into a list of tokens

# %%
stop_words = stopwords.words("english")

def preprocess(sent):
  words=word_tokenize(sent)
  words=[word for word in words if word not in stop_words]
  sent=" ".join(words)
  return sent

# %%
story = []
for filename in os.listdir(dir):
  f = open(os.path.join(dir, filename), mode="r", encoding="latin-1")
  corpus = f.read()
  sents=sent_tokenize(corpus)
  for sent in sents:
    sent=preprocess(sent)
    story.append(simple_preprocess(sent)) #doc into a list of tokens.

# %%
story
# Out:
# [['clash',
#   'kings',
#   'book',
#   'two',
#   'song',
#   'ice',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'the',
#   'comet',
#   'tail',
#   'spread',
#   'across',
#   'dawn',
#   'red',
#   'slash',
#   'bled',
#   'crags',
#   'dragonstone',
#   'like',
#   'wound',
#   'pink',
#   'purple',
#   'sky'],
#  ['the', 'maester', 'stood', 'windswept', 'balcony', 'outside', 'chambers'],
#  ['it', 'ravens', 'came', 'long', 'flight'],
#  ['their',
#   'droppings',
#   'speckled',
#   'gargoyles',
#   'rose',
#   'twelve',
#   'feet',
#   'tall',
#   'either',
#   'side',
#   'hellhound',
#   'wyvern',
#   'two',
#   'thousand',
#   'brooded',
#   'walls',
#   'ancient',
#   'fortress'],
#  ['when',
#   'first',
#   'came',
#   'dragonstone',
#   'army',
#   'stone',
#   'grotesques',
#   'made',
#   'uneasy',
#   'years',
#   'passed',
#   'grown',
#   'used'],
#  ['now', 'thought', 'old', 'friends'],
#  ['the', 'three', 'watched', 'sky', 'together', 'foreboding'],
#  ['the', 'maester', 'believe', 'omens'],
#  ['and', 'yet'],
#  [],
#  [],
#  ['old',
#   'cressen',
#   'never',
#   'seen',
#   'comet',
#   'half',
#   'bright',
#   'yet',
#   'color',
#   'terrible',
#   'color',
#   'color',
#   'blood',
#   'flame',
#   'sunsets'],
#  ['he', 'wondered', 'gargoyles', 'ever', 'seen', 'like'],
#  ['they', 'much', 'longer', 'would', 'still', 'long', 'gone'],
#  ['if', 'stone', 'tongues', 'could', 'speak'],
#  [],
#  [],
#  ['such', 'folly'],
#  ['he',
#   'leaned',
#   'battlement',
#   'sea',
#   'crashing',
#   'beneath',
#   'black',
#   'stone',
#   'rough',
#   'beneath',
#   'fingers'],
#  ['talking', 'gargoyles', 'prophecies', 'sky'],
#  ['old', 'done', 'man', 'grown', 'giddy', 'child'],
#  ['had',
#   'lifetime',
#   'hard',
#   'won',
#   'wisdom',
#   'fled',
#   'along',
#   'health',
#   'strength'],
#  ['he', 'maester', 'trained', 'chained', 'great', 'citadel', 'oldtown'],
#  ['what', 'come', 'superstition', 'filled', 'head', 'ignorant', 'fieldhand'],
#  ['and', 'yet'],
#  [],
#  [],
#  ['yet'],
#  [],
#  [],
#  ['comet',
#   'burned',
#   'even',
#   'day',
#   'pale',
#   'grey',
#   'steam',
#   'rose',
#   'hot',
#   'vents',
#   'dragonmont',
#   'behind',
#   'castle',
#   'yestermorn',
#   'white',
#   'raven',
#   'brought',
#   'word',
#   'citadel',
#   'word',
#   'long',
#   'expected',
#   'less',
#   'fearful',
#   'word',
#   'summer',
#   'end'],
#  ['omens'],
#  ['too', 'many', 'deny'],
#  ['what', 'mean'],
#  ['wanted', 'cry'],
#  ['page', 'maester', 'cressen', 'visitors'],
#  ['pylos',
#   'spoke',
#   'softly',
#   'loath',
#   'disturb',
#   'cressen',
#   'solemn',
#   'meditations'],
#  ['had', 'known', 'drivel', 'filled', 'head', 'would', 'shouted'],
#  ['the', 'princess', 'would', 'see', 'white', 'raven'],
#  ['ever', 'correct', 'pylos', 'called', 'princess', 'lord', 'father', 'king'],
#  ['king',
#   'smoking',
#   'rock',
#   'great',
#   'salt',
#   'sea',
#   'yet',
#   'king',
#   'nonetheless'],
#  ['her', 'fool'],
#  ['the',
#   'old',
#   'man',
#   'turned',
#   'away',
#   'dawn',
#   'keeping',
#   'hand',
#   'wyvern',
#   'steady'],
#  ['help', 'chair', 'show'],
#  ['taking', 'arm', 'pylos', 'led', 'inside'],
#  ['in',
#   'youth',
#   'cressen',
#   'walked',
#   'briskly',
#   'far',
#   'eightieth',
#   'name',
#   'day',
#   'legs',
#   'frail',
#   'unsteady'],
#  ['two',
#   'years',
#   'past',
#   'fallen',
#   'shattered',
#   'hip',
#   'never',
#   'mended',
#   'properly'],
#  ['last',
#   'year',
#   'took',
#   'ill',
#   'citadel',
#   'sent',
#   'pylos',
#   'oldtown',
#   'mere',
#   'days',
#   'lord',
#   'stannis',
#   'closed',
#   'isle'],
#  [],
#  [],
#  ['help', 'labors', 'said', 'cressen', 'knew', 'truth'],
#  ['pylos', 'come', 'replace', 'died'],
#  ['he', 'mind'],
#  ['someone', 'must', 'take', 'place', 'sooner', 'would', 'like'],
#  [],
#  [],
#  ['he', 'let', 'younger', 'man', 'settle', 'behind', 'books', 'papers'],
#  ['go', 'bring'],
#  ['it', 'ill', 'keep', 'lady', 'waiting'],
#  ['he',
#   'waved',
#   'hand',
#   'feeble',
#   'gesture',
#   'haste',
#   'man',
#   'longer',
#   'capable',
#   'hastening'],
#  ['his',
#   'flesh',
#   'wrinkled',
#   'spotted',
#   'skin',
#   'papery',
#   'thin',
#   'could',
#   'see',
#   'web',
#   'veins',
#   'shape',
#   'bones',
#   'beneath'],
#  ['and', 'trembled', 'hands', 'sure', 'deft'],
#  [],
#  [],
#  ['when', 'pylos', 'returned', 'girl', 'came', 'shy', 'ever'],
#  ['behind',
#   'shuffling',
#   'hopping',
#   'queer',
#   'sideways',
#   'walk',
#   'came',
#   'fool'],
#  ['on',
#   'head',
#   'mock',
#   'helm',
#   'fashioned',
#   'old',
#   'tin',
#   'bucket',
#   'rack',
#   'deer',
#   'antlers',
#   'strapped',
#   'crown',
#   'hung',
#   'cowbells'],
#  ['with',
#   'every',
#   'lurching',
#   'step',
#   'bells',
#   'rang',
#   'different',
#   'voice',
#   'clang',
#   'dang',
#   'bong',
#   'dong',
#   'ring',
#   'ling',
#   'clong',
#   'clong',
#   'clong'],
#  ['who', 'comes', 'see', 'us', 'early', 'pylos'],
#  ['cressen', 'said'],
#  ['it', 'patches', 'maester'],
#  ['guileless', 'blue', 'eyes', 'blinked'],
#  ['hers', 'pretty', 'face', 'alas'],
#  ['the',
#   'child',
#   'lord',
#   'father',
#   'square',
#   'jut',
#   'jaw',
#   'mother',
#   'unfortunate',
#   'ears',
#   'along',
#   'disfigurement',
#   'legacy',
#   'bout',
#   'greyscale',
#   'almost',
#   'claimed',
#   'crib'],
#  ['across',
#   'half',
#   'one',
#   'cheek',
#   'well',
#   'neck',
#   'flesh',
#   'stiff',
#   'dead',
#   'skin',
#   'cracked',
#   'flaking',
#   'mottled',
#   'black',
#   'grey',
#   'stony',
#   'touch'],
#  ['pylos', 'said', 'might', 'see', 'white', 'raven'],
#  ['indeed', 'may', 'cressen', 'answered'],
#  ['as', 'would', 'ever', 'deny'],
#  ['she', 'denied', 'often', 'time'],
#  ['her', 'name', 'shireen'],
#  ['she',
#   'would',
#   'ten',
#   'next',
#   'name',
#   'day',
#   'saddest',
#   'child',
#   'maester',
#   'cressen',
#   'ever',
#   'known'],
#  ['her',
#   'sadness',
#   'shame',
#   'old',
#   'man',
#   'thought',
#   'another',
#   'mark',
#   'failure'],
#  ['maester',
#   'pylos',
#   'kindness',
#   'bring',
#   'bird',
#   'rookery',
#   'lady',
#   'shireen'],
#  ['it', 'would', 'pleasure'],
#  ['pylos',
#   'polite',
#   'youth',
#   'five',
#   'and',
#   'twenty',
#   'yet',
#   'solemn',
#   'man',
#   'sixty'],
#  ['if', 'humor', 'life', 'needed'],
#  ['grim',
#   'places',
#   'needed',
#   'lightening',
#   'solemnity',
#   'dragonstone',
#   'grim',
#   'beyond',
#   'doubt',
#   'lonely',
#   'citadel',
#   'wet',
#   'waste',
#   'surrounded',
#   'storm',
#   'salt',
#   'smoking',
#   'shadow',
#   'mountain',
#   'back'],
#  ['maester',
#   'must',
#   'go',
#   'sent',
#   'cressen',
#   'come',
#   'lord',
#   'twelve',
#   'years',
#   'past',
#   'served',
#   'served',
#   'well'],
#  ['yet', 'never', 'loved', 'dragonstone', 'ever', 'felt', 'truly', 'home'],
#  ['of',
#   'late',
#   'woke',
#   'restless',
#   'dreams',
#   'red',
#   'woman',
#   'figured',
#   'disturbingly',
#   'often',
#   'know'],
#  ['page',
#   'the',
#   'fool',
#   'turned',
#   'patched',
#   'piebald',
#   'head',
#   'watch',
#   'pylos',
#   'climb',
#   'steep',
#   'iron',
#   'steps',
#   'rookery'],
#  ['his', 'bells', 'rang', 'motion'],
#  ['under', 'sea', 'birds', 'scales', 'feathers', 'said', 'clang', 'langing'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['even', 'fool', 'patchface', 'sorry', 'thing'],
#  ['perhaps',
#   'could',
#   'evoke',
#   'gales',
#   'laughter',
#   'quip',
#   'sea',
#   'taken',
#   'power',
#   'along',
#   'half',
#   'wits',
#   'memory'],
#  ['he',
#   'soft',
#   'obese',
#   'subject',
#   'twitches',
#   'trembles',
#   'incoherent',
#   'often'],
#  ['the', 'girl', 'one', 'laughed', 'one', 'cared', 'lived', 'died'],
#  ['an', 'ugly', 'little', 'girl', 'sad', 'fool', 'maester', 'makes', 'three'],
#  [],
#  [],
#  ['tale', 'make', 'men', 'weep'],
#  ['sit', 'child'],
#  ['cressen', 'beckoned', 'closer'],
#  ['this', 'early', 'come', 'calling', 'scarce', 'past', 'dawn'],
#  ['you', 'snug', 'bed'],
#  ['bad', 'dreams', 'shireen', 'told'],
#  ['about', 'dragons'],
#  ['they', 'coming', 'eat'],
#  ['the',
#   'child',
#   'plagued',
#   'nightmares',
#   'far',
#   'back',
#   'maester',
#   'cressen',
#   'could',
#   'recall'],
#  ['we', 'talked', 'said', 'gently'],
#  ['the', 'dragons', 'come', 'life'],
#  ['they', 'carved', 'stone', 'child'],
#  ['in',
#   'olden',
#   'days',
#   'island',
#   'westernmost',
#   'outpost',
#   'great',
#   'freehold',
#   'valyria'],
#  ['it',
#   'valyrians',
#   'raised',
#   'citadel',
#   'ways',
#   'shaping',
#   'stone',
#   'since',
#   'lost',
#   'us'],
#  ['castle',
#   'must',
#   'towers',
#   'wherever',
#   'two',
#   'walls',
#   'meet',
#   'angle',
#   'defense'],
#  ['the',
#   'valyrians',
#   'fashioned',
#   'towers',
#   'shape',
#   'dragons',
#   'make',
#   'fortress',
#   'seem',
#   'fearsome',
#   'crowned',
#   'walls',
#   'thousand',
#   'gargoyles',
#   'instead',
#   'simple',
#   'crenellations'],
#  ['he',
#   'took',
#   'small',
#   'pink',
#   'hand',
#   'frail',
#   'spotted',
#   'one',
#   'gave',
#   'gentle',
#   'squeeze'],
#  ['so', 'see', 'nothing', 'fear'],
#  ['shireen', 'unconvinced'],
#  ['what', 'thing', 'sky'],
#  ['dalla',
#   'matrice',
#   'talking',
#   'well',
#   'dalla',
#   'said',
#   'heard',
#   'red',
#   'woman',
#   'tell',
#   'mother',
#   'dragonshreath'],
#  ['if', 'dragons', 'breathing', 'mean', 'coming', 'life'],
#  ['the',
#   'red',
#   'woman',
#   'maester',
#   'cressen',
#   'thought',
#   'sourly',
#   'illenough',
#   'filled',
#   'head',
#   'mother',
#   'madness',
#   'must',
#   'poison',
#   'daughter',
#   'dreams',
#   'well'],
#  ['he', 'would', 'stern', 'word', 'dalla', 'warn', 'spread', 'tales'],
#  ['the', 'thing', 'sky', 'comet', 'sweet', 'child'],
#  ['star', 'tail', 'lost', 'heavens'],
#  ['it', 'gone', 'soon', 'enough', 'never', 'seen', 'lifetimes'],
#  ['watch', 'see'],
#  ['shireen', 'gave', 'brave', 'little', 'nod'],
#  ['mother', 'said', 'white', 'raven', 'means', 'summer', 'anymore'],
#  ['that', 'lady'],
#  ['the', 'white', 'ravens', 'fly', 'citadel'],
#  ['cressen',
#   'fingers',
#   'went',
#   'chain',
#   'neck',
#   'link',
#   'forged',
#   'different',
#   'metal',
#   'symbolizing',
#   'mastery',
#   'another',
#   'branch',
#   'learning',
#   'maester',
#   'collar',
#   'mark',
#   'order'],
#  ['in',
#   'pride',
#   'youth',
#   'worn',
#   'easily',
#   'seemed',
#   'heavy',
#   'metal',
#   'cold',
#   'skin'],
#  ['they',
#   'larger',
#   'ravens',
#   'clever',
#   'bred',
#   'carry',
#   'important',
#   'messages'],
#  ['this',
#   'one',
#   'came',
#   'tell',
#   'us',
#   'conclave',
#   'met',
#   'considered',
#   'reports',
#   'measurements',
#   'made',
#   'maesters',
#   'realm',
#   'declared',
#   'great',
#   'summer',
#   'done',
#   'last'],
#  ['ten',
#   'years',
#   'two',
#   'turns',
#   'sixteen',
#   'days',
#   'lasted',
#   'longest',
#   'summer',
#   'living',
#   'memory'],
#  ['will', 'get', 'cold'],
#  ['shireen', 'summer', 'child', 'never', 'known', 'true', 'cold'],
#  ['in', 'time', 'cressen', 'replied'],
#  ['if',
#   'gods',
#   'good',
#   'grant',
#   'us',
#   'warm',
#   'autumn',
#   'bountiful',
#   'harvests',
#   'might',
#   'prepare',
#   'winter',
#   'come'],
#  ['the',
#   'smallfolk',
#   'said',
#   'long',
#   'summer',
#   'meant',
#   'even',
#   'longer',
#   'winter',
#   'maester',
#   'saw',
#   'reason',
#   'frighten',
#   'child',
#   'tales'],
#  ['page', 'patchface', 'rang', 'bells'],
#  ['it', 'always', 'summer', 'sea', 'intoned'],
#  ['the',
#   'merwives',
#   'wear',
#   'nennymoans',
#   'hair',
#   'weave',
#   'gowns',
#   'silver',
#   'seaweed'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['shireen', 'giggled'],
#  ['like', 'gown', 'silver', 'seaweed'],
#  ['under', 'sea', 'snows', 'said', 'fool', 'rain', 'dry', 'bone'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['will', 'truly', 'snow'],
#  ['child', 'asked'],
#  ['it', 'cressen', 'said'],
#  ['but', 'years', 'yet', 'pray', 'long'],
#  ['ah', 'pylos', 'bird'],
#  ['shireen', 'gave', 'cry', 'delight'],
#  ['even',
#   'cressen',
#   'admit',
#   'bird',
#   'made',
#   'impressive',
#   'sight',
#   'white',
#   'snow',
#   'larger',
#   'hawk',
#   'bright',
#   'black',
#   'eyes',
#   'meant',
#   'mere',
#   'albino',
#   'truebred',
#   'white',
#   'raven',
#   'citadel'],
#  ['here', 'called'],
#  ['the',
#   'raven',
#   'spread',
#   'wings',
#   'leapt',
#   'air',
#   'flapped',
#   'noisily',
#   'across',
#   'room',
#   'land',
#   'table',
#   'beside'],
#  ['ll', 'see', 'breakfast', 'pylos', 'announced'],
#  ['cressen', 'nodded'],
#  ['this', 'lady', 'shireen', 'told', 'raven'],
#  ['the', 'bird', 'bobbed', 'pale', 'head', 'bowing'],
#  ['lady', 'croaked'],
#  ['lady'],
#  ['the', 'child', 'mouth', 'gaped', 'open'],
#  ['it', 'talks'],
#  ['words'],
#  ['as', 'said', 'clever', 'birds'],
#  ['clever',
#   'bird',
#   'clever',
#   'man',
#   'clever',
#   'clever',
#   'fool',
#   'said',
#   'patchface',
#   'jangling'],
#  ['oh', 'clever', 'clever', 'clever', 'fool'],
#  ['he', 'began', 'sing'],
#  ['the',
#   'shadows',
#   'come',
#   'dance',
#   'lord',
#   'dance',
#   'lord',
#   'dance',
#   'lord',
#   'sang',
#   'hopping',
#   'one',
#   'foot',
#   'back'],
#  ['the', 'shadows', 'come', 'stay', 'lord', 'stay', 'lord', 'stay', 'lord'],
#  ['he', 'jerked', 'head', 'word', 'bells', 'antlers', 'sending', 'clangor'],
#  ['the',
#   'white',
#   'raven',
#   'screamed',
#   'went',
#   'flapping',
#   'away',
#   'perch',
#   'iron',
#   'railing',
#   'rookery',
#   'stairs'],
#  ['shireen', 'seemed', 'grow', 'smaller'],
#  ['he', 'sings', 'time'],
#  ['told', 'stop', 'wo'],
#  ['it', 'makes', 'scared'],
#  ['make', 'stop'],
#  ['and'],
#  ['old', 'man', 'wondered'],
#  ['once', 'might', 'silenced', 'forever'],
#  [],
#  [],
#  ['patchface', 'come', 'boy'],
#  ['lord',
#   'steffon',
#   'cherished',
#   'memory',
#   'found',
#   'volantis',
#   'across',
#   'narrow',
#   'sea'],
#  ['the',
#   'king',
#   'the',
#   'old',
#   'king',
#   'aerys',
#   'ii',
#   'targaryen',
#   'quite',
#   'mad',
#   'dayshad',
#   'sent',
#   'lordship',
#   'seek',
#   'bride',
#   'prince',
#   'rhaegar',
#   'sisters',
#   'wed',
#   'we',
#   'found',
#   'splendid',
#   'fool',
#   'wrote',
#   'cressen',
#   'fortnight',
#   'return',
#   'home',
#   'fruitless',
#   'mission'],
#  ['only', 'boy', 'yet', 'nimble', 'monkey', 'witty', 'dozen', 'courtiers'],
#  ['he', 'juggles', 'riddles', 'magic', 'sing', 'prettily', 'four', 'tongues'],
#  ['we', 'bought', 'freedom', 'hope', 'bring', 'home', 'us'],
#  ['robert',
#   'delighted',
#   'perhaps',
#   'time',
#   'even',
#   'teach',
#   'stannis',
#   'laugh'],
#  ['it', 'saddened', 'cressen', 'remember', 'letter'],
#  ['no',
#   'one',
#   'ever',
#   'taught',
#   'stannis',
#   'laugh',
#   'least',
#   'boy',
#   'patchface'],
#  ['the',
#   'storm',
#   'came',
#   'suddenly',
#   'howling',
#   'shipbreaker',
#   'bay',
#   'proved',
#   'truth',
#   'name'],
#  ['the',
#   'lord',
#   'two',
#   'masted',
#   'galley',
#   'windproud',
#   'broke',
#   'within',
#   'sight',
#   'castle'],
#  ['from',
#   'parapets',
#   'two',
#   'eldest',
#   'sons',
#   'watched',
#   'father',
#   'ship',
#   'smashed',
#   'rocks',
#   'swallowed',
#   'waters'],
#  ['hundred',
#   'oarsmen',
#   'sailors',
#   'went',
#   'lord',
#   'steffon',
#   'baratheon',
#   'lady',
#   'wife',
#   'days',
#   'thereafter',
#   'every',
#   'tide',
#   'left',
#   'fresh',
#   'crop',
#   'swollen',
#   'corpses',
#   'strand',
#   'storm',
#   'end'],
#  ['page', 'the', 'boy', 'washed', 'third', 'day'],
#  ['maester', 'cressen', 'come', 'rest', 'help', 'put', 'names', 'dead'],
#  ['when',
#   'found',
#   'fool',
#   'naked',
#   'skin',
#   'white',
#   'wrinkled',
#   'powdered',
#   'wet',
#   'sand'],
#  ['cressen',
#   'thought',
#   'another',
#   'corpse',
#   'jornmy',
#   'grabbed',
#   'ankles',
#   'drag',
#   'burial',
#   'wagon',
#   'boy',
#   'coughed',
#   'water',
#   'sat'],
#  ['to',
#   'dying',
#   'day',
#   'jornmy',
#   'sworn',
#   'patchface',
#   'flesh',
#   'clammy',
#   'cold'],
#  ['no', 'one', 'ever', 'explained', 'two', 'days', 'fool', 'lost', 'sea'],
#  ['the',
#   'fisherfolk',
#   'liked',
#   'say',
#   'mermaid',
#   'taught',
#   'breathe',
#   'water',
#   'return',
#   'seed'],
#  ['patchface', 'said', 'nothing'],
#  ['the',
#   'witty',
#   'clever',
#   'lad',
#   'lord',
#   'steffon',
#   'written',
#   'never',
#   'reached',
#   'storm',
#   'end',
#   'boy',
#   'found',
#   'someone',
#   'else',
#   'broken',
#   'body',
#   'mind',
#   'hardly',
#   'capable',
#   'speech',
#   'much',
#   'less',
#   'wit'],
#  ['yet', 'fool', 'face', 'left', 'doubt'],
#  ['it',
#   'fashion',
#   'free',
#   'city',
#   'volantis',
#   'tattoo',
#   'faces',
#   'slaves',
#   'servants',
#   'neck',
#   'scalp',
#   'boy',
#   'skin',
#   'patterned',
#   'squares',
#   'red',
#   'green',
#   'motley'],
#  ['the',
#   'wretch',
#   'mad',
#   'pain',
#   'use',
#   'anyone',
#   'least',
#   'declared',
#   'old',
#   'ser',
#   'harbert',
#   'castellan',
#   'storm',
#   'end',
#   'years'],
#  ['the', 'kindest', 'thing', 'could', 'one', 'fill', 'cup', 'milk', 'poppy'],
#  ['painless', 'sleep', 'end'],
#  ['he', 'bless', 'wit'],
#  ['but', 'cressen', 'refused', 'end'],
#  ['whether',
#   'patchface',
#   'gotten',
#   'joy',
#   'victory',
#   'could',
#   'say',
#   'even',
#   'today',
#   'many',
#   'years',
#   'later'],
#  ['the',
#   'shadows',
#   'come',
#   'dance',
#   'lord',
#   'dance',
#   'lord',
#   'dance',
#   'lord',
#   'fool',
#   'sang',
#   'swinging',
#   'head',
#   'making',
#   'bells',
#   'clang',
#   'clatter'],
#  ['bong', 'dong', 'ring', 'ling', 'bong', 'dong'],
#  ['lord', 'white', 'raven', 'shrieked'],
#  ['lord', 'lord', 'lord'],
#  ['fool', 'sings', 'maester', 'told', 'anxious', 'princess'],
#  ['you', 'must', 'take', 'words', 'heart'],
#  ['on',
#   'morrow',
#   'may',
#   'remember',
#   'another',
#   'song',
#   'one',
#   'never',
#   'heard'],
#  ['he', 'sing', 'prettily', 'four', 'tongues', 'lord', 'steffon', 'written'],
#  [],
#  [],
#  ['pylos', 'strode', 'door'],
#  ['maester', 'pardons'],
#  ['you', 'forgotten', 'porridge', 'cressen', 'said', 'amused'],
#  ['that', 'unlike', 'pylos'],
#  ['maester', 'ser', 'davos', 'returned', 'last', 'night'],
#  ['they', 'talking', 'kitchen'],
#  ['thought', 'would', 'want', 'know'],
#  ['davos'],
#  [],
#  [],
#  ['last', 'night', 'say'],
#  ['where'],
#  ['with', 'king'],
#  ['they', 'together', 'night'],
#  ['there',
#   'time',
#   'lord',
#   'stannis',
#   'would',
#   'woken',
#   'matter',
#   'hour',
#   'give',
#   'counsel'],
#  ['told', 'cressen', 'complained'],
#  ['woken'],
#  ['he', 'disentangled', 'fingers', 'shireen'],
#  ['pardons', 'lady', 'must', 'speak', 'lord', 'father'],
#  ['pylos', 'give', 'arm'],
#  ['there', 'many', 'steps', 'castle', 'seems', 'add', 'every', 'night', 'vex'],
#  ['shireen',
#   'patchface',
#   'followed',
#   'child',
#   'soon',
#   'grew',
#   'restless',
#   'old',
#   'man',
#   'creeping',
#   'pace',
#   'dashed',
#   'ahead',
#   'fool',
#   'lurching',
#   'cowbells',
#   'clanging',
#   'madly'],
#  ['castles',
#   'friendly',
#   'places',
#   'frail',
#   'cressen',
#   'reminded',
#   'descended',
#   'turnpike',
#   'stairs',
#   'page',
#   'sea',
#   'dragon',
#   'tower'],
#  ['lord',
#   'stannis',
#   'would',
#   'found',
#   'chamber',
#   'painted',
#   'table',
#   'atop',
#   'stone',
#   'drum',
#   'dragonstone',
#   'central',
#   'keep',
#   'named',
#   'way',
#   'ancient',
#   'walls',
#   'boomed',
#   'rumbled',
#   'storms'],
#  ['to',
#   'reach',
#   'must',
#   'cross',
#   'gallery',
#   'pass',
#   'middle',
#   'inner',
#   'walls',
#   'guardian',
#   'gargoyles',
#   'black',
#   'iron',
#   'gates',
#   'ascend',
#   'steps',
#   'cressen',
#   'cared',
#   'contemplate'],
#  ['young',
#   'men',
#   'climbed',
#   'steps',
#   'two',
#   'time',
#   'old',
#   'men',
#   'bad',
#   'hips',
#   'every',
#   'one',
#   'torment'],
#  ['but',
#   'lord',
#   'stannis',
#   'would',
#   'think',
#   'come',
#   'maester',
#   'resigned',
#   'ordeal'],
#  ['he', 'pylos', 'help', 'least', 'grateful'],
#  ['shuffling',
#   'along',
#   'gallery',
#   'passed',
#   'row',
#   'tall',
#   'arched',
#   'windows',
#   'commanding',
#   'views',
#   'outer',
#   'bailey',
#   'curtain',
#   'wall',
#   'fishing',
#   'village',
#   'beyond'],
#  ['yard',
#   'archers',
#   'firing',
#   'practice',
#   'butts',
#   'call',
#   'notch',
#   'draw',
#   'loose'],
#  ['their',
#   'arrows',
#   'made',
#   'sound',
#   'like',
#   'flock',
#   'birds',
#   'taking',
#   'wing'],
#  ['guardsmen',
#   'strode',
#   'wallwalks',
#   'peering',
#   'gargoyles',
#   'host',
#   'camped',
#   'without'],
#  ['the',
#   'morning',
#   'air',
#   'hazy',
#   'smoke',
#   'cookfires',
#   'three',
#   'thousand',
#   'men',
#   'sat',
#   'break',
#   'fasts',
#   'beneath',
#   'banners',
#   'lords'],
#  ['past', 'sprawl', 'camp', 'anchorage', 'crowded', 'ships'],
#  ['no',
#   'craft',
#   'come',
#   'within',
#   'sight',
#   'dragonstone',
#   'past',
#   'half',
#   'year',
#   'allowed',
#   'leave'],
#  ['lord',
#   'stannis',
#   'fury',
#   'triple',
#   'decked',
#   'war',
#   'galley',
#   'three',
#   'hundred',
#   'oars',
#   'looked',
#   'almost',
#   'small',
#   'beside',
#   'big',
#   'bellied',
#   'carracks',
#   'cogs',
#   'surrounded'],
#  ['the',
#   'guardsmen',
#   'outside',
#   'stone',
#   'drum',
#   'knew',
#   'maesters',
#   'sight',
#   'passed'],
#  ['wait', 'cressen', 'told', 'pylos', 'within'],
#  ['it', 'best', 'see', 'alone'],
#  ['it', 'long', 'climb', 'maester'],
#  ['cressen', 'smiled'],
#  ['you', 'think', 'forgotten'],
#  ['climbed', 'steps', 'often', 'know', 'one', 'name'],
#  ['halfway', 'regretted', 'decision'],
#  ['he',
#   'stopped',
#   'catch',
#   'breath',
#   'ease',
#   'pain',
#   'hip',
#   'heard',
#   'scuff',
#   'boots',
#   'stone',
#   'came',
#   'face',
#   'to',
#   'face',
#   'ser',
#   'davos',
#   'seaworth',
#   'descending'],
#  ['davos',
#   'slight',
#   'man',
#   'low',
#   'birth',
#   'written',
#   'plain',
#   'upon',
#   'common',
#   'face'],
#  ['well',
#   'worn',
#   'green',
#   'cloak',
#   'stained',
#   'salt',
#   'spray',
#   'faded',
#   'sun',
#   'draped',
#   'thin',
#   'shoulders',
#   'brown',
#   'doublet',
#   'breeches',
#   'matched',
#   'brown',
#   'eyes',
#   'hair'],
#  ['about', 'neck', 'pouch', 'worn', 'leather', 'hung', 'thong'],
#  ['his',
#   'small',
#   'beard',
#   'well',
#   'peppered',
#   'grey',
#   'wore',
#   'leather',
#   'glove',
#   'maimed',
#   'left',
#   'hand'],
#  ['when', 'saw', 'cressen', 'checked', 'descent'],
#  ['ser', 'davos', 'maester', 'said'],
#  ['when', 'return'],
#  ['in', 'black', 'morning'],
#  ['my', 'favorite', 'time'],
#  ['it',
#   'said',
#   'one',
#   'ever',
#   'handled',
#   'ship',
#   'night',
#   'half',
#   'well',
#   'davos',
#   'shorthand'],
#  ['before',
#   'lord',
#   'stannis',
#   'knighted',
#   'notorious',
#   'elusive',
#   'smuggler',
#   'seven',
#   'kingdoms'],
#  ['and'],
#  ['the', 'man', 'shook', 'head'],
#  ['it', 'warned'],
#  ['they', 'rise', 'maester'],
#  ['not'],
#  ['they', 'love'],
#  ['no', 'cressen', 'thought'],
#  ['nor', 'ever'],
#  ['he', 'strong', 'able'],
#  [],
#  [],
#  ['aye', 'past', 'point', 'wisdom'],
#  [],
#  [],
#  ['yet', 'enough'],
#  ['it', 'never', 'enough'],
#  ['you', 'spoke'],
#  ['page', 'all'],
#  ['no'],
#  ['only', 'would', 'see'],
#  ['they', 'love', 'either', 'highborns'],
#  ['to', 'll', 'always', 'onion', 'knight'],
#  ['his',
#   'left',
#   'hand',
#   'closed',
#   'stubby',
#   'fingers',
#   'locking',
#   'fist',
#   'stannis',
#   'hacked',
#   'ends',
#   'last',
#   'joint',
#   'thumb'],
#  ['broke',
#   'bread',
#   'gulian',
#   'swann',
#   'old',
#   'penrose',
#   'tarths',
#   'consented',
#   'midnight',
#   'meeting',
#   'grove'],
#  ['the',
#   'others',
#   'well',
#   'beric',
#   'dondarrion',
#   'gone',
#   'missing',
#   'say',
#   'dead',
#   'lord',
#   'caron',
#   'renly'],
#  ['bryce', 'orange', 'rainbow', 'guard'],
#  ['the', 'rainbow', 'guard'],
#  ['renly',
#   'made',
#   'kingsguard',
#   'onetime',
#   'smuggler',
#   'explained',
#   'seven',
#   'wear',
#   'white'],
#  ['each', 'one', 'color'],
#  ['loras', 'tyrell', 'lord', 'commander'],
#  ['it',
#   'sort',
#   'notion',
#   'would',
#   'appeal',
#   'renly',
#   'baratheon',
#   'splendid',
#   'new',
#   'order',
#   'knighthood',
#   'gorgeous',
#   'new',
#   'raiment',
#   'proclaim'],
#  ['even',
#   'boy',
#   'renly',
#   'loved',
#   'bright',
#   'colors',
#   'rich',
#   'fabrics',
#   'loved',
#   'games',
#   'well'],
#  ['look'],
#  ['would', 'shout', 'ran', 'laughing', 'halls', 'storm', 'end'],
#  ['look', 'dragon', 'look', 'wizard', 'look', 'look', 'rain', 'god'],
#  ['the',
#   'bold',
#   'little',
#   'boy',
#   'wild',
#   'black',
#   'hair',
#   'laughing',
#   'eyes',
#   'man',
#   'grown',
#   'one',
#   'and',
#   'twenty',
#   'still',
#   'played',
#   'games'],
#  ['look', 'king', 'cressen', 'thought', 'sadly'],
#  ['oh',
#   'renly',
#   'renly',
#   'dear',
#   'sweet',
#   'child',
#   'know',
#   'doing',
#   'and',
#   'would',
#   'care'],
#  ['anyone', 'cares', 'me', 'what', 'reasons', 'lords', 'give', 'refusals'],
#  ['asked', 'ser', 'davos'],
#  ['well',
#   'gave',
#   'soft',
#   'words',
#   'blunt',
#   'made',
#   'excuses',
#   'promises',
#   'lied'],
#  ['he', 'shrugged'],
#  ['in', 'end', 'words', 'wind'],
#  ['you', 'could', 'bring', 'hope'],
#  ['only', 'false', 'sort', 'davos', 'said'],
#  ['he', 'truth'],
#  ['maester',
#   'cressen',
#   'remembered',
#   'day',
#   'davos',
#   'knighted',
#   'siege',
#   'storm',
#   'end'],
#  ['lord',
#   'stannis',
#   'small',
#   'garrison',
#   'held',
#   'castle',
#   'close',
#   'year',
#   'great',
#   'host',
#   'lords',
#   'tyrell',
#   'redwyne'],
#  ['even',
#   'sea',
#   'closed',
#   'watched',
#   'day',
#   'night',
#   'redwyne',
#   'galleys',
#   'flying',
#   'burgundy',
#   'banners',
#   'arbor'],
#  ['within',
#   'storm',
#   'end',
#   'horses',
#   'long',
#   'since',
#   'eaten',
#   'dogs',
#   'cats',
#   'gone',
#   'garrison',
#   'roots',
#   'rats'],
#  ['then', 'came', 'night', 'moon', 'new', 'black', 'clouds', 'hid', 'stars'],
#  ['cloaked',
#   'darkness',
#   'davos',
#   'smuggler',
#   'dared',
#   'redwyne',
#   'cordon',
#   'rocks',
#   'shipbreaker',
#   'bay',
#   'alike'],
#  ['his',
#   'little',
#   'ship',
#   'black',
#   'hull',
#   'black',
#   'sails',
#   'black',
#   'oars',
#   'hold',
#   'crammed',
#   'onions',
#   'salt',
#   'fish'],
#  ['little',
#   'enough',
#   'yet',
#   'kept',
#   'garrison',
#   'alive',
#   'long',
#   'enough',
#   'eddard',
#   'stark',
#   'reach',
#   'storm',
#   'end',
#   'break',
#   'siege'],
#  ['lord',
#   'stannis',
#   'rewarded',
#   'davos',
#   'choice',
#   'lands',
#   'cape',
#   'wrath',
#   'small',
#   'keep',
#   'knight',
#   'honors'],
#  [],
#  [],
#  ['also',
#   'decreed',
#   'lose',
#   'joint',
#   'finger',
#   'left',
#   'hand',
#   'pay',
#   'years',
#   'smuggling'],
#  ['davos',
#   'submitted',
#   'condition',
#   'stannis',
#   'wield',
#   'knife',
#   'would',
#   'accept',
#   'punishment',
#   'lesser',
#   'hands'],
#  ['the',
#   'lord',
#   'used',
#   'butcher',
#   'cleaver',
#   'better',
#   'cut',
#   'clean',
#   'true'],
#  ['afterward',
#   'davos',
#   'chosen',
#   'name',
#   'seaworth',
#   'new',
#   'made',
#   'house',
#   'took',
#   'banner',
#   'black',
#   'ship',
#   'pale',
#   'grey',
#   'field',
#   'with',
#   'onion',
#   'sails'],
#  ['the',
#   'onetime',
#   'smuggler',
#   'fond',
#   'saying',
#   'lord',
#   'stannis',
#   'done',
#   'boon',
#   'giving',
#   'four',
#   'less',
#   'fingernails',
#   'clean',
#   'trim'],
#  ['no',
#   'cressen',
#   'thought',
#   'man',
#   'like',
#   'would',
#   'give',
#   'false',
#   'hope',
#   'soften',
#   'hard',
#   'truth'],
#  ['ser',
#   'davos',
#   'truth',
#   'bitter',
#   'draught',
#   'even',
#   'man',
#   'like',
#   'lord',
#   'stannis'],
#  ['he',
#   'thinks',
#   'returning',
#   'king',
#   'landing',
#   'fullness',
#   'power',
#   'tear',
#   'enemies',
#   'claim',
#   'rightfully'],
#  ['yet'],
#  [],
#  [],
#  ['page', 'takes', 'meager', 'host', 'king', 'landing', 'die'],
#  ['he', 'numbers'],
#  ['told', 'much', 'know', 'pride'],
#  ['davos', 'held', 'gloved', 'hand'],
#  ['my', 'fingers', 'grow', 'back', 'man', 'bends', 'sense'],
#  ['the', 'old', 'man', 'sighed'],
#  ['you', 'done', 'could'],
#  ['now', 'must', 'add', 'voice'],
#  ['wearily', 'resumed', 'climb'],
#  ['lord',
#   'stannis',
#   'baratheon',
#   'refuge',
#   'great',
#   'round',
#   'room',
#   'walls',
#   'bare',
#   'black',
#   'stone',
#   'four',
#   'tall',
#   'narrow',
#   'windows',
#   'looked',
#   'four',
#   'points',
#   'compass'],
#  ['in',
#   'center',
#   'chamber',
#   'great',
#   'table',
#   'took',
#   'name',
#   'massive',
#   'slab',
#   'carved',
#   'wood',
#   'fashioned',
#   'command',
#   'aegon',
#   'targaryen',
#   'days',
#   'conquest'],
#  ['the',
#   'painted',
#   'table',
#   'fifty',
#   'feet',
#   'long',
#   'perhaps',
#   'half',
#   'wide',
#   'widest',
#   'point',
#   'less',
#   'four',
#   'feet',
#   'across',
#   'narrowest'],
#  ['aegon',
#   'carpenters',
#   'shaped',
#   'land',
#   'westeros',
#   'sawing',
#   'bay',
#   'peninsula',
#   'table',
#   'nowhere',
#   'ran',
#   'straight'],
#  ['on',
#   'surface',
#   'darkened',
#   'near',
#   'three',
#   'hundred',
#   'years',
#   'varnish',
#   'painted',
#   'seven',
#   'kingdoms',
#   'aegon',
#   'day',
#   'rivers',
#   'mountains',
#   'castles',
#   'cities',
#   'lakes',
#   'forests'],
#  ['there',
#   'single',
#   'chair',
#   'room',
#   'carefully',
#   'positioned',
#   'precise',
#   'place',
#   'dragonstone',
#   'occupied',
#   'coast',
#   'westeros',
#   'raised',
#   'give',
#   'good',
#   'view',
#   'tabletop'],
#  ['seated',
#   'chair',
#   'man',
#   'tight',
#   'laced',
#   'leather',
#   'jerkin',
#   'breeches',
#   'roughspun',
#   'brown',
#   'wool'],
#  ['when', 'maester', 'cressen', 'entered', 'glanced'],
#  ['knew', 'would', 'come', 'old', 'man', 'whether', 'summoned'],
#  ['there', 'hint', 'warmth', 'voice', 'seldom'],
#  ['stannis',
#   'baratheon',
#   'lord',
#   'dragonstone',
#   'grace',
#   'gods',
#   'rightful',
#   'heir',
#   'iron',
#   'throne',
#   'seven',
#   'kingdoms',
#   'westeros',
#   'broad',
#   'shoulder',
#   'sinewy',
#   'limb',
#   'tightness',
#   'face',
#   'flesh',
#   'spoke',
#   'leather',
#   'cured',
#   'sun',
#   'tough',
#   'steel'],
#  ['hard', 'word', 'men', 'used', 'spoke', 'stannis', 'hard'],
#  ['though',
#   'yet',
#   'five',
#   'and',
#   'thirty',
#   'fringe',
#   'thin',
#   'black',
#   'hair',
#   'remained',
#   'head',
#   'circling',
#   'behind',
#   'ears',
#   'like',
#   'shadow',
#   'crown'],
#  ['his',
#   'brother',
#   'late',
#   'king',
#   'robert',
#   'grown',
#   'beard',
#   'final',
#   'years'],
#  ['maester',
#   'cressen',
#   'never',
#   'seen',
#   'said',
#   'wild',
#   'thing',
#   'thick',
#   'flerce'],
#  ['as', 'answer', 'stannis', 'kept', 'whiskers', 'cropped', 'tight', 'short'],
#  ['they',
#   'lay',
#   'like',
#   'blue',
#   'black',
#   'shadow',
#   'across',
#   'square',
#   'jaw',
#   'bony',
#   'hollows',
#   'cheeks'],
#  ['his',
#   'eyes',
#   'open',
#   'wounds',
#   'beneath',
#   'heavy',
#   'brows',
#   'blue',
#   'dark',
#   'sea',
#   'night'],
#  ['his',
#   'mouth',
#   'would',
#   'given',
#   'despair',
#   'even',
#   'drollest',
#   'fools',
#   'mouth',
#   'made',
#   'frowns',
#   'scowls',
#   'sharply',
#   'worded',
#   'commands',
#   'thin',
#   'pale',
#   'lips',
#   'clenched',
#   'muscles',
#   'mouth',
#   'forgotten',
#   'smile',
#   'never',
#   'known',
#   'laugh'],
#  ['sometimes',
#   'world',
#   'grew',
#   'still',
#   'silent',
#   'night',
#   'maester',
#   'cressen',
#   'fancied',
#   'could',
#   'hear',
#   'lord',
#   'stannis',
#   'grinding',
#   'teeth',
#   'half',
#   'castle',
#   'away'],
#  ['once', 'would', 'woken', 'old', 'man', 'said'],
#  ['once', 'young'],
#  ['now', 'old', 'sick', 'need', 'sleep'],
#  ['stannis',
#   'never',
#   'learned',
#   'soften',
#   'speech',
#   'dissemble',
#   'flatter',
#   'said',
#   'thought',
#   'like',
#   'could',
#   'damned'],
#  ['knew', 'learn', 'davos', 'say', 'soon', 'enough'],
#  ['you', 'always'],
#  ['would', 'help', 'cressen', 'said'],
#  ['met', 'davos', 'stair'],
#  ['and', 'told', 'suppose'],
#  ['man', 'tongue', 'shortened', 'along', 'fingers'],
#  ['he', 'would', 'made', 'poor', 'envoy'],
#  ['he', 'made', 'poor', 'envoy', 'case'],
#  ['the', 'storm', 'lords', 'rise'],
#  ['it', 'seems', 'like', 'page', 'justice', 'cause', 'means', 'nothing'],
#  ['the',
#   'cravenly',
#   'ones',
#   'sit',
#   'behind',
#   'walls',
#   'waiting',
#   'see',
#   'wind',
#   'rises',
#   'likely',
#   'triumph'],
#  ['the', 'bold', 'ones', 'already', 'declared', 'renly'],
#  ['for', 'enly'],
#  ['he', 'spat', 'name', 'like', 'poison', 'tongue'],
#  ['your', 'brother', 'lord', 'storm', 'end', 'past', 'thirteen', 'years'],
#  ['these',
#   'lords',
#   'sworn',
#   'bannermen',
#   'his',
#   'stannis',
#   'broke',
#   'rights',
#   'mine'],
#  ['never', 'asked', 'dragonstone'],
#  ['never', 'wanted'],
#  ['took', 'robert', 'enemies', 'commanded', 'root'],
#  ['built', 'fleet', 'work', 'dutiful', 'younger', 'brother', 'elder', 'renly'],
#  ['and', 'robert', 'thanks'],
#  ['he',
#   'names',
#   'lord',
#   'dragonstone',
#   'gives',
#   'storm',
#   'end',
#   'incomes',
#   'renly'],
#  ['storm',
#   'end',
#   'belonged',
#   'house',
#   'baratheon',
#   'three',
#   'hundred',
#   'years',
#   'rights',
#   'passed',
#   'robert',
#   'took',
#   'iron',
#   'throne'],
#  ['it', 'old', 'grievance', 'deeply', 'felt', 'never'],
#  ['here',
#   'heart',
#   'lord',
#   'weakness',
#   'dragonstone',
#   'old',
#   'strong',
#   'though',
#   'commanded',
#   'allegiance',
#   'handful',
#   'lesser',
#   'lords',
#   'whose',
#   'stony',
#   'island',
#   'holdings',
#   'thinly',
#   'peopled',
#   'yield',
#   'men',
#   'stannis',
#   'needed'],
#  ['even',
#   'sellswords',
#   'brought',
#   'across',
#   'narrow',
#   'sea',
#   'free',
#   'cities',
#   'myr',
#   'lys',
#   'host',
#   'camped',
#   'outside',
#   'walls',
#   'far',
#   'small',
#   'bring',
#   'power',
#   'house',
#   'lannister'],
#  ['robert',
#   'injustice',
#   'maester',
#   'cressen',
#   'replied',
#   'carefully',
#   'yet',
#   'sound',
#   'reasons'],
#  ['dragonstone', 'long', 'seat', 'house', 'targaryen'],
#  ['he', 'needed', 'man', 'strength', 'rule', 'renly', 'child'],
#  ['he',
#   'child',
#   'still',
#   'stannis',
#   'declared',
#   'anger',
#   'ringing',
#   'loud',
#   'empty',
#   'hall',
#   'thieving',
#   'child',
#   'thinks',
#   'snatch',
#   'crown',
#   'brow'],
#  ['what', 'renly', 'ever', 'done', 'earn', 'throne'],
#  ['he',
#   'sits',
#   'council',
#   'jests',
#   'littlefinger',
#   'tourneys',
#   'dons',
#   'splendid',
#   'suit',
#   'armor',
#   'allows',
#   'knocked',
#   'horse',
#   'better',
#   'man'],
#  ['that', 'sum', 'brother', 'renly', 'thinks', 'ought', 'king'],
#  ['ask', 'gods', 'inflict', 'brothers'],
#  ['answer', 'gods'],
#  ['you', 'seldom', 'answer', 'days', 'seems'],
#  ['who', 'maesters', 'renly'],
#  ['perchance', 'send', 'might', 'like', 'counsel', 'better'],
#  ['what', 'think', 'maester', 'said', 'brother', 'decided', 'steal', 'crown'],
#  ['what', 'counsel', 'colleague', 'offer', 'traitor', 'blood', 'mine'],
#  ['it',
#   'would',
#   'surprise',
#   'lord',
#   'renly',
#   'sought',
#   'counsel',
#   'your',
#   'grace'],
#  ['the',
#   'youngest',
#   'lord',
#   'steffon',
#   'three',
#   'sons',
#   'grown',
#   'man',
#   'bold',
#   'heedless',
#   'acted',
#   'impulse',
#   'rather',
#   'calculation'],
#  ['in',
#   'much',
#   'else',
#   'renly',
#   'like',
#   'brother',
#   'robert',
#   'utterly',
#   'unlike',
#   'stannis'],
#  ['your', 'grace', 'stannis', 'repeated', 'bitterly'],
#  ['you', 'mock', 'king', 'style', 'yet', 'king'],
#  ['dragonstone', 'rocks', 'narrow', 'sea', 'kingdom'],
#  ['he',
#   'descended',
#   'steps',
#   'chair',
#   'stand',
#   'table',
#   'shadow',
#   'falling',
#   'across',
#   'mouth',
#   'blackwater',
#   'rush',
#   'painted',
#   'forest',
#   'king',
#   'landing',
#   'stood'],
#  ['there',
#   'stood',
#   'brooding',
#   'realm',
#   'sought',
#   'claim',
#   'near',
#   'hand',
#   'yet',
#   'far',
#   'away'],
#  ['tonight', 'sup', 'lords', 'bannermen'],
#  ['celtigar', 'velaryon', 'bar', 'emmon', 'whole', 'paltry', 'lot'],
#  ['poor', 'crop', 'truth', 'told', 'brothers', 'left'],
#  ['that',
#   'lysene',
#   'pirate',
#   'salladhor',
#   'saan',
#   'latest',
#   'tally',
#   'owe',
#   'morosh',
#   'myrman',
#   'caution',
#   'talk',
#   'tides',
#   'autumn',
#   'gales',
#   'lord',
#   'sunglass',
#   'mutters',
#   'piously',
#   'seven'],
#  ['celtigar', 'want', 'know', 'storm', 'lords', 'joining', 'page', 'us'],
#  ['velaryon', 'threaten', 'take', 'levies', 'home', 'unless', 'strike'],
#  ['what', 'tell'],
#  ['what', 'must'],
#  ['your',
#   'true',
#   'enemies',
#   'lannisters',
#   'lord',
#   'maester',
#   'cressen',
#   'answered'],
#  ['if',
#   'brother',
#   'make',
#   'common',
#   'cause',
#   'them',
#   'treat',
#   'renly',
#   'stannis',
#   'answered',
#   'tone',
#   'brooked',
#   'argument'],
#  ['not', 'calls', 'king'],
#  ['not', 'renly', 'maester', 'yielded'],
#  ['his', 'lord', 'stubborn', 'proud', 'set', 'mind', 'changing'],
#  ['others', 'might', 'serve', 'needs', 'well'],
#  ['eddard',
#   'stark',
#   'son',
#   'proclaimed',
#   'king',
#   'north',
#   'power',
#   'winterfell',
#   'riverrun',
#   'behind'],
#  ['green', 'boy', 'said', 'stannis', 'another', 'false', 'king'],
#  ['am', 'accept', 'broken', 'realm'],
#  ['surely',
#   'half',
#   'kingdom',
#   'better',
#   'none',
#   'cressen',
#   'said',
#   'help',
#   'boy',
#   'avenge',
#   'father',
#   'murder',
#   'why',
#   'avenge',
#   'eddard',
#   'stark'],
#  ['the', 'man', 'nothing'],
#  ['oh', 'robert', 'loved', 'sure'],
#  ['loved', 'brother', 'often', 'hear'],
#  ['brother', 'ned', 'stark', 'would', 'never', 'known', 'way', 'treated'],
#  ['held',
#   'storm',
#   'end',
#   'watching',
#   'good',
#   'men',
#   'starve',
#   'mace',
#   'tyrell',
#   'paxter',
#   'redwyne',
#   'feasted',
#   'within',
#   'sight',
#   'walls'],
#  ['did', 'robert', 'thank'],
#  ['no'],
#  ['he', 'thanked', 'stark', 'lifting', 'siege', 'rats', 'radishes'],
#  ['built', 'fleet', 'robert', 'command', 'took', 'dragonstone', 'name'],
#  ['did',
#   'take',
#   'hand',
#   'say',
#   'well',
#   'done',
#   'brother',
#   'whatever',
#   'without'],
#  ['no',
#   'blamed',
#   'letting',
#   'willem',
#   'darry',
#   'steal',
#   'away',
#   'viserys',
#   'babe',
#   'could',
#   'stopped'],
#  ['sat',
#   'council',
#   'fifteen',
#   'years',
#   'helping',
#   'jon',
#   'arryn',
#   'rule',
#   'realm',
#   'robert',
#   'drank',
#   'whored',
#   'jon',
#   'died',
#   'brother',
#   'name',
#   'hand'],
#  ['no',
#   'went',
#   'galloping',
#   'dear',
#   'friend',
#   'ned',
#   'stark',
#   'offered',
#   'honor'],
#  ['and', 'small', 'good', 'either', 'them'],
#  ['be', 'may', 'lord', 'maester', 'cressen', 'said', 'gently'],
#  ['great', 'wrongs', 'done', 'past', 'dust'],
#  ['the', 'future', 'may', 'yet', 'join', 'starks'],
#  ['there', 'others', 'might', 'sound', 'well'],
#  ['what', 'lady', 'arryn'],
#  ['if', 'queen', 'murdered', 'husband', 'surely', 'want', 'justice'],
#  ['she', 'young', 'son', 'jon', 'arryn', 'heir'],
#  ['if',
#   'betroth',
#   'shireen',
#   'him',
#   'the',
#   'boy',
#   'weak',
#   'sickly',
#   'lord',
#   'stannis',
#   'objected'],
#  ['even', 'father', 'saw', 'asked', 'foster', 'dragonstone'],
#  ['service',
#   'page',
#   'might',
#   'done',
#   'good',
#   'damnable',
#   'lannister',
#   'woman',
#   'lord',
#   'arryn',
#   'poisoned',
#   'could',
#   'done',
#   'lysa',
#   'hides',
#   'eyrie'],
#  ['she', 'll', 'never', 'part', 'boy', 'promise', 'that'],
#  ['then', 'must', 'send', 'shireen', 'eyrie', 'maester', 'urged'],
#  ['dragonstone', 'grim', 'home', 'child'],
#  ['let', 'fool', 'go', 'familiar', 'face'],
#  ['familiar', 'hideous'],
#  ['stannis', 'furrowed', 'brow', 'thought'],
#  ['still'],
#  [],
#  [],
#  ['perhaps', 'worth', 'trying'],
#  [],
#  [],
#  ['must',
#   'rightful',
#   'lord',
#   'seven',
#   'kingdoms',
#   'beg',
#   'help',
#   'widow',
#   'women',
#   'usurpers'],
#  ['woman', 'voice', 'asked', 'sharply'],
#  ['maester', 'cressen', 'turned', 'bowed', 'head'],
#  ['my', 'lady', 'said', 'chagrined', 'heard', 'enter'],
#  ['page', 'lord', 'stannis', 'scowled'],
#  ['beg'],
#  ['of', 'anyone'],
#  ['mind', 'remember', 'woman'],
#  ['pleased', 'hear', 'lord'],
#  ['lady',
#   'selyse',
#   'tall',
#   'husband',
#   'thin',
#   'body',
#   'thin',
#   'face',
#   'prominent',
#   'ears',
#   'sharp',
#   'nose',
#   'faintest',
#   'hint',
#   'mustache',
#   'upper',
#   'lip'],
#  ['she',
#   'plucked',
#   'daily',
#   'cursed',
#   'regularly',
#   'yet',
#   'never',
#   'failed',
#   'return'],
#  ['her', 'eyes', 'pale', 'mouth', 'stern', 'voice', 'whip'],
#  ['she', 'cracked'],
#  ['lady', 'arryn', 'owes', 'allegiance', 'starks', 'brother', 'renly', 'rest'],
#  ['you', 'one', 'true', 'king'],
#  ['it', 'would', 'fitting', 'plead', 'bargain', 'rightfully', 'grace', 'god'],
#  ['god', 'said', 'gods'],
#  ['the',
#   'red',
#   'woman',
#   'heart',
#   'soul',
#   'turning',
#   'gods',
#   'seven',
#   'kingdoms',
#   'old',
#   'new',
#   'worship',
#   'one',
#   'called',
#   'lord',
#   'light'],
#  ['your',
#   'god',
#   'keep',
#   'grace',
#   'said',
#   'lord',
#   'stannis',
#   'share',
#   'wife',
#   'fervent',
#   'new',
#   'faith'],
#  ['it', 'swords', 'need', 'blessings'],
#  ['do', 'army', 'hidden', 'somewhere', 've', 'told'],
#  ['there', 'affection', 'tone'],
#  ['stannis', 'always', 'uncomfortable', 'around', 'women', 'even', 'wife'],
#  ['when',
#   'gone',
#   'king',
#   'landing',
#   'sit',
#   'robert',
#   'council',
#   'left',
#   'selyse',
#   'dragonstone',
#   'daughter'],
#  ['his',
#   'letters',
#   'visits',
#   'fewer',
#   'duty',
#   'marriage',
#   'bed',
#   'twice',
#   'year',
#   'took',
#   'joy',
#   'sons',
#   'hoped',
#   'never',
#   'come'],
#  ['my', 'brothers', 'uncles', 'cousins', 'armies', 'told'],
#  ['house', 'florent', 'rally', 'banner'],
#  ['house', 'florent', 'field', 'two', 'thousand', 'swords', 'best'],
#  ['it',
#   'said',
#   'stannis',
#   'knew',
#   'strength',
#   'every',
#   'house',
#   'seven',
#   'kingdoms'],
#  ['and', 'deal', 'faith', 'brothers', 'uncles', 'lady'],
#  ['the',
#   'florent',
#   'lands',
#   'lie',
#   'close',
#   'highgarden',
#   'lord',
#   'uncle',
#   'risk',
#   'mace',
#   'tyrell',
#   'wrath'],
#  ['there', 'another', 'way'],
#  ['lady', 'selyse', 'moved', 'closer'],
#  ['look', 'windows', 'lord'],
#  ['there', 'sign', 'waited', 'blazoned', 'sky'],
#  ['red', 'red', 'flame', 'red', 'fiery', 'heart', 'true', 'god'],
#  ['banner', 'and'],
#  ['see',
#   'unfurls',
#   'across',
#   'heavens',
#   'like',
#   'dragon',
#   'hot',
#   'breath',
#   'lord',
#   'dragonstone'],
#  ['it', 'means', 'time', 'come', 'your', 'grace'],
#  ['nothing', 'certain'],
#  ['you',
#   'meant',
#   'sail',
#   'desolate',
#   'rock',
#   'aegon',
#   'conqueror',
#   'sailed',
#   'sweep'],
#  ['say', 'word', 'embrace', 'power', 'lord', 'light'],
#  ['how', 'many', 'swords', 'lord', 'light', 'put', 'hand'],
#  ['stannis', 'demanded'],
#  ['all',
#   'need',
#   'wife',
#   'promised',
#   'the',
#   'swords',
#   'storm',
#   'end',
#   'highgarden',
#   'start',
#   'lords',
#   'bannermen'],
#  ['davos', 'would', 'tell', 'different', 'stannis', 'said'],
#  ['those', 'swords', 'sworn', 'renly'],
#  ['they', 'love', 'charming', 'young', 'brother', 'loved', 'robert'],
#  [],
#  [],
#  ['never', 'loved'],
#  ['yes', 'answered', 'renly', 'die'],
#  [],
#  [],
#  ['stannis',
#   'looked',
#   'lady',
#   'narrowed',
#   'eyes',
#   'cressen',
#   'could',
#   'hold',
#   'tongue'],
#  ['thought'],
#  ['your', 'grace', 'whatever', 'follies', 'renly', 'committed', 'follies'],
#  ['call', 'treasons'],
#  ['stannis', 'turned', 'back', 'wife'],
#  ['my',
#   'brother',
#   'young',
#   'strong',
#   'vast',
#   'host',
#   'around',
#   'rainbow',
#   'knights'],
#  ['page', 'melisandre', 'gazed', 'flames', 'seen', 'dead'],
#  ['cressen', 'horrorstruck'],
#  ['fratricide'],
#  [],
#  [],
#  ['lord', 'evil', 'unthinkable'],
#  [],
#  [],
#  ['please', 'listen'],
#  ['lady', 'selyse', 'gave', 'measured', 'look'],
#  ['and', 'tell', 'maester'],
#  ['how',
#   'might',
#   'win',
#   'half',
#   'kingdom',
#   'goes',
#   'starks',
#   'knees',
#   'sells',
#   'daughter',
#   'lysa',
#   'arryn'],
#  ['heard', 'counsel', 'cressen', 'lord', 'stannis', 'said'],
#  ['now', 'hear'],
#  ['you', 'dismissed'],
#  ['maester', 'cressen', 'bent', 'stiff', 'knee'],
#  ['he',
#   'could',
#   'feel',
#   'lady',
#   'selyse',
#   'eyes',
#   'back',
#   'shuffled',
#   'slowly',
#   'across',
#   'room'],
#  ['by', 'time', 'reached', 'bottom', 'steps', 'could', 'stand', 'erect'],
#  ['help', 'said', 'pylos'],
#  ['when',
#   'safe',
#   'back',
#   'rooms',
#   'cressen',
#   'sent',
#   'younger',
#   'man',
#   'away',
#   'limped',
#   'balcony',
#   'stand',
#   'gargoyles',
#   'stare',
#   'sea'],
#  ['one',
#   'salladhor',
#   'saan',
#   'warships',
#   'sweeping',
#   'past',
#   'castle',
#   'gaily',
#   'striped',
#   'hull',
#   'slicing',
#   'greygreen',
#   'waters',
#   'oars',
#   'rose',
#   'fell'],
#  ['he', 'watched', 'vanished', 'behind', 'headland'],
#  ['would', 'fears', 'could', 'vanish', 'easily'],
#  ['had', 'lived', 'long'],
#  ['when',
#   'maester',
#   'donned',
#   'collar',
#   'put',
#   'aside',
#   'hope',
#   'children',
#   'yet',
#   'cressen',
#   'oft',
#   'felt',
#   'father',
#   'nonetheless'],
#  ['robert', 'stannis', 'renly'],
#  [],
#  [],
#  ['three', 'sons', 'raised', 'angry', 'sea', 'claimed', 'lord', 'steffon'],
#  ['had', 'done', 'ill', 'must', 'watch', 'one', 'kill'],
#  ['he', 'could', 'allow', 'would', 'allow'],
#  ['the', 'woman', 'heart'],
#  ['not', 'lady', 'selyse', 'one'],
#  ['the', 'red', 'woman', 'servants', 'named', 'afraid', 'speak', 'name'],
#  ['speak', 'name', 'cressen', 'told', 'stone', 'hellhound'],
#  ['melisandre'],
#  ['her'],
#  ['melisandre',
#   'asshai',
#   'sorceress',
#   'shadowbinder',
#   'priestess',
#   'hllor',
#   'lord',
#   'light',
#   'heart',
#   'fire',
#   'god',
#   'flame',
#   'shadow'],
#  ['melisandre',
#   'whose',
#   'madness',
#   'must',
#   'allowed',
#   'spread',
#   'beyond',
#   'dragonstone'],
#  ['his', 'chambers', 'seemed', 'dim', 'gloomy', 'brightness', 'morning'],
#  ['with',
#   'fumbling',
#   'hands',
#   'old',
#   'man',
#   'lit',
#   'candle',
#   'carried',
#   'workroom',
#   'beneath',
#   'rookery',
#   'stair',
#   'ointments',
#   'potions',
#   'medicines',
#   'stood',
#   'neatly',
#   'shelves'],
#  ['on',
#   'bottom',
#   'shelf',
#   'behind',
#   'row',
#   'salves',
#   'squat',
#   'clay',
#   'jars',
#   'found',
#   'vial',
#   'indigo',
#   'glass',
#   'larger',
#   'little',
#   'finger'],
#  ['it', 'rattled', 'shook'],
#  ['cressen', 'blew', 'away', 'layer', 'dust', 'carried', 'back', 'table'],
#  ['collapsing', 'chair', 'pulled', 'stopper', 'spilled', 'vial', 'contents'],
#  ['dozen',
#   'crystals',
#   'larger',
#   'seeds',
#   'rattled',
#   'across',
#   'parchment',
#   'reading'],
#  ['they',
#   'shone',
#   'like',
#   'jewels',
#   'candlelight',
#   'purple',
#   'maester',
#   'found',
#   'thinking',
#   'never',
#   'truly',
#   'seen',
#   'color'],
#  ['the', 'chain', 'around', 'throat', 'felt', 'heavy'],
#  ['he', 'touched', 'one', 'crystals', 'lightly', 'tip', 'little', 'finger'],
#  ['such', 'small', 'thing', 'hold', 'power', 'life', 'death'],
#  ['it',
#   'made',
#   'certain',
#   'plant',
#   'grew',
#   'islands',
#   'jade',
#   'sea',
#   'half',
#   'world',
#   'away'],
#  ['the',
#   'leaves',
#   'aged',
#   'soaked',
#   'wash',
#   'limes',
#   'sugar',
#   'water',
#   'certain',
#   'rare',
#   'spices',
#   'summer',
#   'isles'],
#  ['afterward',
#   'could',
#   'discarded',
#   'potion',
#   'must',
#   'thickened',
#   'ash',
#   'allowed',
#   'crystallize'],
#  ['the',
#   'process',
#   'slow',
#   'difficult',
#   'necessaries',
#   'costly',
#   'hard',
#   'acquire'],
#  ['the',
#   'alchemists',
#   'lys',
#   'knew',
#   'way',
#   'though',
#   'faceless',
#   'men',
#   'braavos'],
#  [],
#  [],
#  ['maesters',
#   'order',
#   'well',
#   'though',
#   'something',
#   'talked',
#   'beyond',
#   'walls',
#   'citadel'],
#  ['all',
#   'world',
#   'knew',
#   'maester',
#   'forged',
#   'silver',
#   'link',
#   'learned',
#   'art',
#   'healing',
#   'but',
#   'world',
#   'preferred',
#   'forget',
#   'men',
#   'knew',
#   'heal',
#   'also',
#   'knew',
#   'kill'],
#  ['page',
#   'cressen',
#   'longer',
#   'recalled',
#   'name',
#   'asshai',
#   'gave',
#   'leaf',
#   'lysene',
#   'poisoners',
#   'crystal'],
#  ['in', 'citadel', 'simply', 'called', 'strangler'],
#  ['dissolved',
#   'wine',
#   'would',
#   'make',
#   'muscles',
#   'man',
#   'throat',
#   'clench',
#   'tighter',
#   'fist',
#   'shutting',
#   'windpipe'],
#  ['they',
#   'said',
#   'victim',
#   'face',
#   'turned',
#   'purple',
#   'little',
#   'crystal',
#   'seed',
#   'death',
#   'grown',
#   'man',
#   'choking',
#   'morsel',
#   'food'],
#  ['and',
#   'night',
#   'lord',
#   'stannis',
#   'would',
#   'feast',
#   'bannermen',
#   'lady',
#   'wife'],
#  [],
#  [],
#  ['red', 'woman', 'melisandre', 'asshai'],
#  ['must', 'rest', 'maester', 'cressen', 'told'],
#  ['must', 'strength', 'come', 'dark'],
#  ['my', 'hands', 'must', 'shake', 'courage', 'flag'],
#  ['it', 'dreadful', 'thing', 'yet', 'must', 'done'],
#  ['if', 'gods', 'surely', 'forgive'],
#  ['he', 'slept', 'poorly', 'late'],
#  ['nap', 'would', 'refresh', 'ordeal', 'ahead'],
#  ['wearily', 'tottered', 'bed'],
#  ['yet',
#   'closed',
#   'eyes',
#   'could',
#   'still',
#   'see',
#   'light',
#   'comet',
#   'red',
#   'flery',
#   'vividly',
#   'alive',
#   'amidst',
#   'darkness',
#   'dreams'],
#  ['perhaps', 'comet', 'thought', 'drowsily', 'last', 'sleep', 'took'],
#  ['an', 'omen', 'blood', 'foretelling', 'murder'],
#  [],
#  [],
#  ['yes'],
#  [],
#  [],
#  ['when',
#   'woke',
#   'full',
#   'dark',
#   'bedchamber',
#   'black',
#   'every',
#   'joint',
#   'body',
#   'ached'],
#  ['cressen', 'pushed', 'head', 'throbbing'],
#  ['clutching', 'cane', 'rose', 'unsteady', 'feet'],
#  ['so', 'late', 'thought'],
#  ['they', 'summon'],
#  ['he',
#   'always',
#   'summoned',
#   'feasts',
#   'seated',
#   'near',
#   'salt',
#   'close',
#   'lord',
#   'stannis'],
#  ['his',
#   'lord',
#   'face',
#   'swam',
#   'man',
#   'boy',
#   'standing',
#   'cold',
#   'shadows',
#   'sun',
#   'shone',
#   'elder',
#   'brother'],
#  ['whatever', 'robert', 'done', 'first', 'better'],
#  ['poor', 'boy'],
#  [],
#  [],
#  ['must', 'hurry', 'sake'],
#  ['the', 'maester', 'found', 'crystals', 'left', 'scooped', 'parchment'],
#  ['cressen',
#   'owned',
#   'hollow',
#   'rings',
#   'poisoners',
#   'lys',
#   'said',
#   'favor',
#   'myriad',
#   'pockets',
#   'great',
#   'small',
#   'sewn',
#   'inside',
#   'loose',
#   'sleeves',
#   'robe'],
#  ['he',
#   'secreted',
#   'strangler',
#   'seeds',
#   'one',
#   'threw',
#   'open',
#   'door',
#   'called',
#   'pylos'],
#  ['where'],
#  ['when', 'heard', 'reply', 'called', 'louder'],
#  ['pylos', 'need', 'help'],
#  ['still', 'came', 'answer'],
#  ['that',
#   'queer',
#   'young',
#   'maester',
#   'cell',
#   'half',
#   'turn',
#   'stair',
#   'within',
#   'easy',
#   'earshot'],
#  ['in', 'end', 'cressen', 'shout', 'servants'],
#  ['make', 'haste', 'told'],
#  ['slept', 'long'],
#  ['they', 'feasting'],
#  [],
#  [],
#  ['drinking'],
#  [],
#  [],
#  ['woken'],
#  ['what', 'happened', 'maester', 'pylos'],
#  ['truly', 'understand'],
#  ['again', 'cross', 'long', 'gallery'],
#  ['night', 'wind', 'whispered', 'great', 'windows', 'sharp', 'smell', 'sea'],
#  ['torches',
#   'flickered',
#   'along',
#   'walls',
#   'dragonstone',
#   'camp',
#   'beyond',
#   'could',
#   'see',
#   'hundreds',
#   'cookfires',
#   'burning',
#   'field',
#   'stars',
#   'fallen',
#   'earth'],
#  ['above', 'comet', 'blazed', 'red', 'malevolent'],
#  ['old', 'wise', 'fear', 'things', 'maester', 'told'],
#  ['the', 'doors', 'great', 'hall', 'set', 'mouth', 'stone', 'dragon'],
#  ['he', 'told', 'servants', 'leave', 'outside'],
#  ['it', 'would', 'better', 'enter', 'alone', 'must', 'appear', 'feeble'],
#  ['leaning',
#   'heavily',
#   'cane',
#   'cressen',
#   'climbed',
#   'last',
#   'steps',
#   'hobbled',
#   'beneath',
#   'gateway',
# ...
#   'seaworth'],
#  ['here',
#   'eat',
#   'fish',
#   'fool',
#   'declared',
#   'happily',
#   'waving',
#   'cod',
#   'like',
#   'scepter'],
#  ['under', 'sea', 'fish', 'eat', 'us'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['ser', 'davos', 'moved', 'aside', 'make', 'room', 'bench'],
#  ['we',
#   'motley',
#   'tonight',
#   'said',
#   'gloomily',
#   'cressen',
#   'seated',
#   'fool',
#   'business',
#   're'],
#  ['the',
#   'red',
#   'woman',
#   'seen',
#   'victory',
#   'flames',
#   'stannis',
#   'means',
#   'press',
#   'claim',
#   'matter',
#   'numbers'],
#  ['before',
#   'done',
#   're',
#   'like',
#   'see',
#   'patchface',
#   'saw',
#   'fearthe',
#   'bottom',
#   'sea'],
#  ['cressen', 'slid', 'hands', 'sleeves', 'warmth'],
#  ['his', 'fingers', 'found', 'hard', 'lumps', 'crystals', 'made', 'wool'],
#  ['lord', 'stannis'],
#  ['page', 'stannis', 'turned', 'red', 'woman', 'lady', 'selyse', 'replied'],
#  ['king', 'stannis'],
#  ['you', 'forget', 'maester'],
#  ['he', 'old', 'mind', 'wanders', 'king', 'told', 'gruffly'],
#  ['what', 'cressen'],
#  ['speak', 'mind'],
#  ['as',
#   'intend',
#   'sail',
#   'vital',
#   'make',
#   'common',
#   'cause',
#   'lord',
#   'stark',
#   'lady',
#   'arryn'],
#  [],
#  [],
#  ['make', 'common', 'cause', 'one', 'stannis', 'baratheon', 'said'],
#  ['no', 'light', 'makes', 'common', 'cause', 'darkness'],
#  ['lady', 'selyse', 'took', 'hand'],
#  ['stannis', 'nodded'],
#  ['the',
#   'starks',
#   'seek',
#   'steal',
#   'half',
#   'kingdom',
#   'even',
#   'lannisters',
#   'stolen',
#   'throne',
#   'sweet',
#   'brother',
#   'swords',
#   'service',
#   'strongholds',
#   'mine',
#   'rights'],
#  ['they', 'usurpers', 'enemies'],
#  ['lost', 'cressen', 'thought', 'despairing'],
#  ['if', 'could', 'somehow', 'approach', 'melisandre', 'unseen'],
#  [],
#  [],
#  ['needed', 'instant', 'access', 'cup'],
#  ['you',
#   'rightful',
#   'heir',
#   'brother',
#   'robert',
#   'true',
#   'lord',
#   'seven',
#   'kingdoms',
#   'king',
#   'andals',
#   'rhoynar',
#   'first',
#   'men',
#   'said',
#   'desperately',
#   'even',
#   'hope',
#   'triumph',
#   'without',
#   'allies'],
#  ['he', 'ally', 'lady', 'selyse', 'said'],
#  ['whilor', 'lord', 'light', 'heart', 'fire', 'god', 'flame', 'shadow'],
#  ['gods',
#   'make',
#   'uncertain',
#   'allies',
#   'best',
#   'old',
#   'man',
#   'insisted',
#   'one',
#   'power'],
#  ['you', 'think'],
#  ['the',
#   'ruby',
#   'melisandre',
#   'throat',
#   'caught',
#   'light',
#   'turned',
#   'head',
#   'instant',
#   'seemed',
#   'glow',
#   'bright',
#   'comet'],
#  ['if', 'speak', 'folly', 'maester', 'ought', 'wear', 'crown'],
#  ['yes', 'lady', 'selyse', 'agreed'],
#  ['patches', 'helm'],
#  ['it', 'suits', 'well', 'old', 'man'],
#  ['put', 'command'],
#  ['under', 'sea', 'one', 'wears', 'hats', 'patchface', 'said'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['lord',
#   'stannis',
#   'eyes',
#   'shadowed',
#   'beneath',
#   'heavy',
#   'brow',
#   'mouth',
#   'tight',
#   'jaw',
#   'worked',
#   'silently'],
#  ['he', 'always', 'ground', 'teeth', 'angry'],
#  ['fool', 'growled', 'last', 'lady', 'wife', 'commands'],
#  ['give', 'cressen', 'helm'],
#  ['no',
#   'old',
#   'maester',
#   'thought',
#   'way',
#   'always',
#   'always',
#   'hard',
#   'yet',
#   'never',
#   'cruel',
#   'never',
#   'understand',
#   'mockery',
#   'understood',
#   'laughter'],
#  ['patchface',
#   'danced',
#   'closer',
#   'cowbells',
#   'ringing',
#   'clang',
#   'lang',
#   'ding',
#   'ding',
#   'clink',
#   'clank',
#   'clink',
#   'clank'],
#  ['the',
#   'maester',
#   'sat',
#   'silent',
#   'fool',
#   'set',
#   'antlered',
#   'bucket',
#   'brow'],
#  ['cressen', 'bowed', 'head', 'beneath', 'weight'],
#  ['his', 'bells', 'clanged'],
#  ['perhaps',
#   'ought',
#   'sing',
#   'counsel',
#   'henceforth',
#   'lady',
#   'selyse',
#   'said'],
#  ['you', 'go', 'far', 'woman', 'lord', 'stannis', 'said'],
#  ['he', 'old', 'man', 'served', 'well'],
#  ['and',
#   'serve',
#   'last',
#   'sweet',
#   'lord',
#   'poor',
#   'lonely',
#   'son',
#   'cressen',
#   'thought',
#   'suddenly',
#   'saw',
#   'way'],
#  ['ser', 'davos', 'cup', 'still', 'half', 'full', 'sour', 'red'],
#  ['he',
#   'found',
#   'hard',
#   'flake',
#   'crystal',
#   'sleeve',
#   'held',
#   'tight',
#   'thumb',
#   'forefinger',
#   'reached',
#   'cup'],
#  ['smooth',
#   'motions',
#   'deft',
#   'must',
#   'fumble',
#   'prayed',
#   'page',
#   'gods',
#   'kind'],
#  ['in', 'blink', 'eye', 'fingers', 'empty'],
#  ['his', 'hands', 'steady', 'years', 'half', 'fluid'],
#  ['davos', 'saw', 'one', 'else', 'certain'],
#  ['cup', 'hand', 'rose', 'feet'],
#  ['mayhaps', 'fool'],
#  ['lady', 'melisandre', 'share', 'cup', 'wine'],
#  ['cup', 'honor', 'god', 'lord', 'light'],
#  ['cup', 'toast', 'power'],
#  ['the', 'red', 'woman', 'studied'],
#  ['if', 'wish'],
#  ['he', 'could', 'feel', 'watching'],
#  ['davos',
#   'clutched',
#   'left',
#   'bench',
#   'catching',
#   'sleeve',
#   'fingers',
#   'lord',
#   'stannis',
#   'shortened'],
#  ['what'],
#  ['whispered'],
#  ['thing',
#   'must',
#   'done',
#   'maester',
#   'cressen',
#   'answered',
#   'sake',
#   'realm',
#   'soul',
#   'lord'],
#  ['he', 'shook', 'davos', 'hand', 'spilling', 'drop', 'wine', 'rushes'],
#  ['she', 'met', 'beneath', 'high', 'table', 'every', 'man', 'eyes', 'upon'],
#  ['but', 'cressen', 'saw'],
#  ['red',
#   'silk',
#   'red',
#   'eyes',
#   'ruby',
#   'red',
#   'throat',
#   'red',
#   'lips',
#   'curled',
#   'faint',
#   'smile',
#   'put',
#   'hand',
#   'atop',
#   'around',
#   'cup'],
#  ['her', 'skin', 'felt', 'hot', 'feverish'],
#  ['it', 'late', 'spill', 'wine', 'maester'],
#  ['no', 'whispered', 'hoarsely'],
#  ['no'],
#  ['as'],
#  ['melisandre', 'asshai', 'took', 'cup', 'hands', 'drank', 'long', 'deep'],
#  ['there', 'half', 'swallow', 'wine', 'remaining', 'offered', 'back'],
#  ['and'],
#  ['his', 'hands', 'shaking', 'made', 'strong'],
#  ['maester', 'citadel', 'must', 'afraid'],
#  ['the', 'wine', 'sour', 'tongue'],
#  ['he', 'let', 'empty', 'cup', 'drop', 'fingers', 'shatter', 'floor'],
#  ['he', 'power', 'lord', 'woman', 'said'],
#  ['and', 'fire', 'cleanses'],
#  ['at', 'throat', 'ruby', 'shimmered', 'redly'],
#  ['cressen', 'tried', 'reply', 'words', 'caught', 'throat'],
#  ['his',
#   'cough',
#   'became',
#   'terrible',
#   'thin',
#   'whistle',
#   'strained',
#   'suck',
#   'air'],
#  ['iron', 'fingers', 'tightened', 'round', 'neck'],
#  ['as',
#   'sank',
#   'knees',
#   'still',
#   'shook',
#   'head',
#   'denying',
#   'denying',
#   'power',
#   'denying',
#   'magic',
#   'denying',
#   'god'],
#  ['and',
#   'cowbells',
#   'peeled',
#   'antlers',
#   'singing',
#   'fool',
#   'fool',
#   'fool',
#   'red',
#   'woman',
#   'looked',
#   'pity',
#   'candle',
#   'flames',
#   'dancing',
#   'red',
#   'red',
#   'eyes'],
#  ['chapter',
#   'arya',
#   'at',
#   'winterfell',
#   'called',
#   'arya',
#   'horseface',
#   'thought',
#   'nothing',
#   'could',
#   'worse',
#   'orphan',
#   'boy',
#   'lommy',
#   'greenhands',
#   'named',
#   'lumpyhead'],
#  ['her', 'head', 'felt', 'lumpy', 'touched'],
#  ['when',
#   'yoren',
#   'dragged',
#   'alley',
#   'thought',
#   'meant',
#   'kill',
#   'sour',
#   'old',
#   'man',
#   'held',
#   'tight',
#   'sawing',
#   'mats',
#   'tangles',
#   'dagger'],
#  ['she',
#   'remembered',
#   'breeze',
#   'sent',
#   'fistfuls',
#   'dirty',
#   'brown',
#   'hair',
#   'skittering',
#   'across',
#   'paving',
#   'stones',
#   'toward',
#   'sept',
#   'father',
#   'died'],
#  ['taking',
#   'men',
#   'boys',
#   'city',
#   'yoren',
#   'growled',
#   'sharp',
#   'steel',
#   'scraped',
#   'head'],
#  ['now', 'hold', 'still', 'boy'],
#  ['by', 'time', 'finished', 'scalp', 'nothing', 'tufts', 'stubble'],
#  ['page', 'afterward', 'told', 'winterfell', 'arry', 'orphan', 'boy'],
#  ['gate', 'hard', 'road', 'another', 'matter'],
#  ['you', 'got', 'long', 'way', 'go', 'bad', 'company'],
#  ['got',
#   'thirty',
#   'time',
#   'men',
#   'boys',
#   'bound',
#   'wall',
#   'thinking',
#   're',
#   'like',
#   'bastard',
#   'brother'],
#  ['he', 'shook'],
#  ['lord', 'eddard', 'gave', 'pick', 'dungeons', 'find', 'little', 'lordlings'],
#  ['this',
#   'lot',
#   'half',
#   'would',
#   'turn',
#   'queen',
#   'quick',
#   'spit',
#   'pardon',
#   'maybe',
#   'silvers'],
#  ['the', 'half', 'rape', 'first'],
#  ['so', 'keep', 'make', 'water', 'woods', 'alone'],
#  ['that', 'll', 'hardest', 'part', 'pissing', 'drink', 'need'],
#  ['leaving', 'king', 'landing', 'easy', 'like', 'said'],
#  ['the',
#   'lannister',
#   'guardsmen',
#   'gate',
#   'stopping',
#   'everyone',
#   'yoren',
#   'called',
#   'one',
#   'name',
#   'wagons',
#   'waved'],
#  ['no', 'one', 'spared', 'arya', 'glance'],
#  ['they',
#   'looking',
#   'highborn',
#   'girl',
#   'daughter',
#   'king',
#   'hand',
#   'skinny',
#   'boy',
#   'hair',
#   'chopped'],
#  ['arya', 'never', 'looked', 'back'],
#  ['she',
#   'wished',
#   'rush',
#   'would',
#   'rise',
#   'wash',
#   'whole',
#   'city',
#   'away',
#   'flea',
#   'bottom',
#   'red',
#   'keep',
#   'great',
#   'sept',
#   'everything',
#   'everyone',
#   'especially',
#   'prince',
#   'joffrey',
#   'mother'],
#  ['but',
#   'knew',
#   'would',
#   'anyhow',
#   'sansa',
#   'still',
#   'city',
#   'would',
#   'wash',
#   'away'],
#  ['when', 'remembered', 'arya', 'decided', 'wish', 'winterfell', 'instead'],
#  ['yoren', 'wrong', 'pissing', 'though'],
#  ['that',
#   'hardest',
#   'part',
#   'lommy',
#   'greenhands',
#   'hot',
#   'pie',
#   'hardest',
#   'part'],
#  ['orphan', 'boys'],
#  ['yoren',
#   'plucked',
#   'streets',
#   'promises',
#   'food',
#   'bellies',
#   'shoes',
#   'feet'],
#  ['the', 'rest', 'found', 'chains'],
#  ['the', 'watch', 'needs', 'good', 'men', 'told', 'set', 'lot'],
#  ['yoren',
#   'taken',
#   'grown',
#   'men',
#   'dungeons',
#   'well',
#   'thieves',
#   'poachers',
#   'rapers',
#   'like'],
#  ['the',
#   'worst',
#   'three',
#   'found',
#   'black',
#   'cells',
#   'must',
#   'scared',
#   'even',
#   'kept',
#   'fettered',
#   'hand',
#   'foot',
#   'back',
#   'wagon',
#   'vowed',
#   'stay',
#   'irons',
#   'way',
#   'wall'],
#  ['one',
#   'nose',
#   'hole',
#   'face',
#   'cut',
#   'gross',
#   'fat',
#   'bald',
#   'one',
#   'pointed',
#   'teeth',
#   'weeping',
#   'sores',
#   'cheeks',
#   'eyes',
#   'like',
#   'nothing',
#   'human'],
#  ['they',
#   'took',
#   'five',
#   'wagons',
#   'king',
#   'landing',
#   'laden',
#   'supplies',
#   'wall',
#   'hides',
#   'bolts',
#   'cloth',
#   'bars',
#   'pig',
#   'iron',
#   'cage',
#   'ravens',
#   'books',
#   'paper',
#   'ink',
#   'bale',
#   'sourleaf',
#   'jars',
#   'oil',
#   'chests',
#   'medicine',
#   'spices'],
#  ['teams',
#   'plow',
#   'horses',
#   'pulled',
#   'wagons',
#   'yoren',
#   'bought',
#   'two',
#   'coursers',
#   'half',
#   'dozen',
#   'donkeys',
#   'boys'],
#  ['arya',
#   'would',
#   'preferred',
#   'real',
#   'horse',
#   'donkey',
#   'better',
#   'riding',
#   'wagon'],
#  ['the', 'men', 'paid', 'mind', 'lucky', 'boys'],
#  ['she',
#   'two',
#   'years',
#   'younger',
#   'youngest',
#   'orphan',
#   'mention',
#   'smaller',
#   'skinnier',
#   'lommy',
#   'hot',
#   'pie',
#   'took',
#   'silence',
#   'mean',
#   'scared',
#   'stupid',
#   'deaf'],
#  ['look',
#   'sword',
#   'lumpyhead',
#   'got',
#   'lommy',
#   'said',
#   'one',
#   'morning',
#   'made',
#   'plodding',
#   'way',
#   'past',
#   'orchards',
#   'wheat',
#   'fields'],
#  ['he',
#   'dyer',
#   'apprentice',
#   'caught',
#   'stealing',
#   'arms',
#   'mottled',
#   'green',
#   'elbow'],
#  ['when', 'laughed', 'brayed', 'like', 'donkeys', 'riding'],
#  ['where', 'gutter', 'rat', 'like', 'lumpyhead', 'get', 'sword'],
#  ['arya', 'chewed', 'lip', 'sullenly'],
#  ['she',
#   'could',
#   'see',
#   'back',
#   'yoren',
#   'faded',
#   'black',
#   'cloak',
#   'ahead',
#   'wagons',
#   'determined',
#   'go',
#   'crying',
#   'help'],
#  ['maybe', 'little', 'squire', 'hot', 'pie', 'put'],
#  ['his',
#   'mother',
#   'baker',
#   'died',
#   'pushed',
#   'cart',
#   'streets',
#   'day',
#   'shouting',
#   'hot',
#   'pies'],
#  ['hot', 'pies'],
#  ['some', 'lordy', 'lord', 'little', 'squire', 'boy'],
#  ['page', 'he', 'ai', 'squire', 'look'],
#  ['bet', 'even', 'real', 'sword'],
#  ['bet', 'play', 'sword', 'made', 'tin'],
#  ['arya', 'hated', 'making', 'fun', 'needle'],
#  ['it',
#   'castle',
#   'forged',
#   'steel',
#   'stupid',
#   'snapped',
#   'turning',
#   'saddle',
#   'glare',
#   'better',
#   'shut',
#   'mouth'],
#  ['the', 'orphan', 'boys', 'hooted'],
#  ['where', 'get', 'blade', 'like', 'lumpyface'],
#  ['hot', 'pie', 'wanted', 'know'],
#  ['lumpyhead', 'corrected', 'lommy'],
#  ['he', 'prob', 'ly', 'stole'],
#  [],
#  ['shouted'],
#  ['jon', 'snow', 'given', 'needle'],
#  ['maybe', 'let', 'call', 'lumpyhead', 'going', 'let', 'call', 'jon', 'thief'],
#  ['if', 'stole', 'could', 'take', 'said', 'hot', 'pie'],
#  ['it', 'anyhow'],
#  ['could', 'use', 'sword', 'like'],
#  ['lommy', 'egged'],
#  ['go', 'take', 'dare'],
#  ['hot', 'pie', 'kicked', 'donkey', 'riding', 'closer'],
#  ['hey', 'lumpyface', 'gim', 'sword'],
#  ['his', 'hair', 'color', 'straw', 'fat', 'face', 'sunburnt', 'peeling'],
#  ['you', 'know', 'use'],
#  ['yes', 'arya', 'could', 'said'],
#  ['killed',
#   'boy',
#   'fat',
#   'boy',
#   'like',
#   'stabbed',
#   'belly',
#   'died',
#   'll',
#   'kill',
#   'let',
#   'alone'],
#  ['only', 'dare'],
#  ['yoren', 'know', 'stableboy', 'afraid', 'might', 'found'],
#  ['arya',
#   'pretty',
#   'sure',
#   'men',
#   'killers',
#   'three',
#   'manacles',
#   'sure',
#   'queen',
#   'looking'],
#  ['look', 'brayed', 'lommy', 'greenhands'],
#  ['bet', 'going', 'cry'],
#  ['you', 'want', 'cry', 'lumpyhead'],
#  ['she', 'cried', 'sleep', 'night', 'dreaming', 'father'],
#  ['come',
#   'morning',
#   'woken',
#   'red',
#   'eyed',
#   'dry',
#   'could',
#   'shed',
#   'another',
#   'tear',
#   'life',
#   'hung'],
#  ['he', 'going', 'wet', 'pants', 'hot', 'pie', 'suggested'],
#  ['leave', 'said', 'boy', 'shaggy', 'black', 'hair', 'rode', 'behind'],
#  ['lommy',
#   'named',
#   'bull',
#   'account',
#   'horned',
#   'helm',
#   'polished',
#   'time',
#   'never',
#   'wore'],
#  ['lommy', 'dare', 'mock', 'bull'],
#  ['he', 'older', 'big', 'age', 'broad', 'chest', 'strong', 'looking', 'arms'],
#  ['you', 'better', 'give', 'hot', 'pie', 'sword', 'arry', 'lommy', 'said'],
#  ['hot', 'pie', 'wants', 'bad'],
#  ['he', 'kicked', 'boy', 'death'],
#  ['he', 'll', 'bet'],
#  ['knocked',
#   'kicked',
#   'balls',
#   'kept',
#   'kicking',
#   'dead',
#   'hot',
#   'pie',
#   'boasted'],
#  ['kicked', 'pieces'],
#  ['his', 'balls', 'broke', 'open', 'bloody', 'cock', 'turned', 'black'],
#  ['you', 'better', 'gim', 'sword'],
#  ['arya', 'slid', 'practice', 'sword', 'belt'],
#  ['you', 'one', 'told', 'hot', 'pie', 'wanting', 'fight'],
#  ['that', 'stick'],
#  ['he', 'rode', 'nearer', 'tried', 'reach', 'needle', 'hilt'],
#  ['page',
#   'arya',
#   'made',
#   'stick',
#   'whistle',
#   'laid',
#   'wood',
#   'across',
#   'donkey',
#   'hindquarters'],
#  ['the', 'animal', 'hawed', 'bucked', 'dumping', 'hot', 'pie', 'ground'],
#  ['she',
#   'vaulted',
#   'donkey',
#   'poked',
#   'gut',
#   'tried',
#   'get',
#   'sat',
#   'back',
#   'grunt'],
#  ['then',
#   'whacked',
#   'across',
#   'face',
#   'nose',
#   'made',
#   'crack',
#   'like',
#   'branch',
#   'breaking'],
#  ['blood', 'dribbled', 'nostrils'],
#  ['when',
#   'hot',
#   'pie',
#   'began',
#   'wail',
#   'arya',
#   'whirled',
#   'toward',
#   'lommy',
#   'greenhands',
#   'sitting',
#   'donkey',
#   'openmouthed'],
#  ['you', 'want', 'sword'],
#  ['yelled'],
#  ['he',
#   'raised',
#   'dyed',
#   'green',
#   'hands',
#   'front',
#   'face',
#   'squealed',
#   'get',
#   'away'],
#  ['the', 'bull', 'shouted', 'behind', 'arya', 'spun'],
#  ['hot', 'pie', 'knees', 'fist', 'closing', 'around', 'big', 'jagged', 'rock'],
#  ['she', 'let', 'throw', 'ducking', 'head', 'sailed', 'past'],
#  ['then', 'flew'],
#  ['he', 'raised', 'hand', 'hit', 'cheek', 'knee'],
#  ['he', 'grabbed', 'danced', 'aside', 'bounced', 'wood', 'back', 'head'],
#  ['he', 'fell', 'got', 'stumbled', 'red', 'face', 'smeared', 'dirt', 'blood'],
#  ['arya', 'slid', 'water', 'dancer', 'stance', 'waited'],
#  ['when',
#   'came',
#   'close',
#   'enough',
#   'lunged',
#   'right',
#   'legs',
#   'hard',
#   'wooden',
#   'sword',
#   'point',
#   'would',
#   'come',
#   'butt',
#   'cheeks'],
#  ['by',
#   'time',
#   'yoren',
#   'pulled',
#   'hot',
#   'pie',
#   'sprawled',
#   'ground',
#   'breeches',
#   'brown',
#   'smelly',
#   'crying',
#   'arya',
#   'whapped'],
#  ['enough',
#   'black',
#   'brother',
#   'roared',
#   'prying',
#   'stick',
#   'sword',
#   'fingers',
#   'want',
#   'kill',
#   'fool'],
#  ['when', 'lommy', 'others', 'started', 'squeal', 'old', 'man', 'turned'],
#  ['shut', 'mouths', 'll', 'shutting'],
#  ['any', 'll', 'tie', 'lot', 'behind', 'wagons', 'drag', 'wall'],
#  ['he', 'spat'],
#  ['and', 'goes', 'twice', 'arry'],
#  ['you', 'come', 'boy'],
#  ['now',
#   'they',
#   'looking',
#   'even',
#   'three',
#   'chained',
#   'manacled',
#   'back',
#   'wagon'],
#  ['the',
#   'fat',
#   'one',
#   'snapped',
#   'pointy',
#   'teeth',
#   'together',
#   'hissed',
#   'arya',
#   'ignored'],
#  ['the',
#   'old',
#   'man',
#   'dragged',
#   'well',
#   'road',
#   'tangle',
#   'trees',
#   'cursing',
#   'muttering'],
#  ...]

# %% [markdown]
# # Step 2: Train the model

# %%
model=gensim.models.Word2Vec(
    window = 7, # number of words in a sequence
    min_count = 2, # Minimum number of allowed in a doc
    workers = 8,
    vector_size = 200, # 100 by default
    epochs = 10
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (9619091, 10171670)

# %% [markdown]
# Number of corpus trained is the same as the len of story

# %%
model.corpus_count
# Out:
# 145020

# %%
len(story)
# Out:
# 145020

# %%
model.epochs
# Out:
# 10

# %% [markdown]
# # Step 3: Test the model

# %%
# Aray and Sansa are sisters
model.wv.similarity("arya","sansa")
# Out:
# 0.7120205

# %%
# Daenerys is the queen
model.wv.similarity("queen","daenerys")
# Out:
# 0.51908207

# %%
# Check the most similar words to the word King
model.wv.most_similar("king")
# Out:
# [('baratheon', 0.6106770038604736),
#  ('realm', 0.5637972950935364),
#  ('royal', 0.5213494300842285),
#  ('tourney', 0.5060192346572876),
#  ('beholden', 0.496696799993515),
#  ('conciliator', 0.4957672953605652),
#  ('usurper', 0.49108681082725525),
#  ('nage', 0.48472994565963745),
#  ('defiled', 0.4735596179962158),
#  ('conqueror', 0.4723212718963623)]

# %%
# Check the does not match word
model.wv.doesnt_match(['jon', 'robb', 'arya', 'sansa', 'bran'])
# Out:
# 'jon'
